4.319322109222412]], "AAAABBAABBAABABABBAA": [[5.411553859710693, 2.4095797538757324]]}{"AAAAAAABBBBAAAAAAAAA": [[18.573383331298828, 1.7818148136138916]], "AAAAAAABBBBAAAAAAABA": [[10.998665809631348, 5.664658069610596]], "AAAAAAABBBBAAABAABAB": [[8.471317291259766, 7.570998191833496]], "BAAAAAABBBBAAAAAAAAB": [[7.623144149780273, 6.978397846221924]], "BAAAAAABBBBAAAAAAABB": [[4.551022529602051, 8.544965744018555]]}{"AAAABBBAABAAABBBAAAA": [[3.7531161308288574, 3.0203564167022705]], "AAAABBBAABBAABBBBAAA": [[0.4553437829017639, 0.20667728781700134]], "AAABBBAAABAAABBBBABA": [[7.693014144897461, 3.948793649673462]], "AAABBBBAABAAABBBBAAB": [[9.369909286499023, -0.6032390594482422]], "AAABBBBAABBAABBABBAA": [[-0.8493399024009705, 1.8471907377243042]]}{"AAAAAABAABBAABBBBAAA": [[12.65634536743164, 0.08900681138038635]], "AAAABABAABBAAABBBAAB": [[13.471299171447754, 2.1686489582061768]], "AABABABAABBAABBBABAA": [[10.929289817810059, 6.016039848327637]], "ABAABABBABBAABBABBAA": [[10.02880573272705, 5.20772123336792]], "BAAABABAABBAABBBAAAB": [[17.628467559814453, 2.8742830753326416]]}{"AAABBAAABBAABABBAAAB": [[14.447354316711426, 0.814801037311554]], "AAABBBAABAAAAABBAAAB": [[11.3650484085083, 1.2700908184051514]], "AAABBBAABAAAAABBABAA": [[2.809763193130493, 8.737719535827637]], "AAABBBAABAABAABBAABA": [[8.214309692382812, 8.558944702148438]], "AABBBBAABBABBAABABAA": [[4.367975234985352, 4.275545120239258]]}'''

# Split the input data into separate JSON objects
json_objects = input_data.split('}{')

# Prepare a list to hold flattened data
flattened_data = []

# Process each JSON object
for json_str in json_objects:
    if not json_str.startswith('{'):
        json_str = '{' + json_str
    if not json_str.endswith('}'):
        json_str = json_str + '}'
    data = json.loads(json_str)
    for key, value in data.items():
        # Flatten the nested list structure
        for sub_value in value:
            flattened_data.append([key] + sub_value)

# Write to CSV
with open('output.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    # Write the header
    writer.writerow(['Key', 'Value1', 'Value2'])
    # Write the data
    writer.writerows(flattened_data)

print("Data has been written to output.csv")
# Out:
# Data has been written to output.csv

# %%
import alphashape
import numpy as np
import os
import pandas as pd


def make_alpha_hull(xy, alpha=1):
    alpha_shape = alphashape.alphashape(xy, alpha)
    xH, yH = alpha_shape.boundary.coords.xy
    return np.vstack([xH, yH]).T


all_data = []
for keyword in ['random', 'kmeans']:
    df = pd.read_csv(os.path.join('data', 'embeddings', f'polymers-umap-{keyword}.txt'), header=None, names=['Sequence', 'Z0', 'Z1'])
    all_data.append(df)

orig_data = pd.concat(all_data)
orig_hull = make_alpha_hull(orig_data.loc[:, 'Z0':'Z1'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv
 'ABBAAAAABBAABABBABAA',
 'ABBABAAABAAAABABBBAA',
 'ABBABABAABABABAAAABA',
 'ABBBAAABAAABAAAABBBA',
 'ABBBBBAAAAAAAABABABA',
 'BAAAAABABBBAAABBAABA',
 'BAAAABBABBAAAABBBAAA',
 'BAAABBABAAABABABBAAA',
 'BAAABBABABAABABAAAAB',
 'BAABAAABAABAABBBABAA',
 'BAABAAABBBABAAAABAAB',
 'BAABAABABABAAABBBAAA',
 'BABAABABAABABBBAAAAA',
 'BABAABBABAABAAAAABBA',
 'BABAABBABBBAAAAAABAA',
 'BABABABABAABAAAAABAB',
 'BABABBBAABABABAAAAAA',
 'BABBAAABBABBAAAABAAA',
 'BABBABAABAAAAABBABAA',
 'BBAAAABABABBAAAAABAB',
 'BBAABAABAABABAABABAA',
 'BBABBAAAABAABABAAAAB',
 'BBABBABAAABBAABAAAAA',
 'BBBAABABAAAABAABABAA']

# %%
import torch
import model_utils

# load the RNN
model_ensemble = []
model_path = os.path.join('models', 'gru-opt-cv10-sym')
for i in range(10):
    model = torch.jit.load(os.path.join(model_path, f'fold-{i:02d}-scripted.pt'), map_location='cpu')
    model.eval()
    model_ensemble.append(model)

# keyword = 'active'
# with open(f'/Users/wfr5091/Downloads/m3-{keyword}-embeddings-rev.json', 'r') as fid:
#     data = json.load(fid)

# sequences = list(data.keys())
# sequences = ["AAABBBBBAAABAAABBBAA"]

AB = {'A': 0, 'B': 1}
int_seq = np.array([[int(AB[x]) for x in s] for s in sequences])

predictions = []
for model in model_ensemble:
    out = model_utils.predict_from_model(model, int_seq)
    predictions.append(out)
z_pred = np.array(predictions).mean(axis=0)

AB_rev = {'A': 1, 'B': 0}
int_seq = np.array([[int(AB_rev[x]) for x in s] for s in sequences])

predictions = []
for model in model_ensemble:
    out = model_utils.predict_from_model(model, int_seq)
    predictions.append(out)
z_pred_rev = np.array(predictions).mean(axis=0)

# run the RNN predictions on these sequences
# results = model_utils.run_sequences(sequences, model_ensemble)

# %%
print(json.dumps(z_pred.tolist()))
# Out:
# [[4.292383193969727, -0.25006383657455444], [6.934352874755859, 0.17687058448791504], [8.823698997497559, 2.9980125427246094], [11.894545555114746, 2.165661334991455], [17.103500366210938, 4.284074306488037], [7.075537204742432, 4.372811317443848], [12.361146926879883, 5.613211631774902], [5.466960430145264, -3.094849109649658], [3.790335178375244, 4.1439361572265625], [1.1957086324691772, 7.1608123779296875], [14.7631196975708, 3.398747205734253], [9.233248710632324, 5.350840091705322], [-0.5818469524383545, 0.4395579695701599], [14.389513969421387, 1.6659637689590454], [1.4413098096847534, 3.74341082572937], [-2.647355556488037, 6.485861301422119], [16.047393798828125, 2.5074164867401123], [5.996227741241455, 8.871652603149414], [17.462554931640625, 1.5963369607925415], [5.255317211151123, 6.4647536277771], [-3.3975586891174316, 0.5558291673660278], [4.433489799499512, 1.8924119472503662], [8.554353713989258, -1.287595510482788], [8.862946510314941, -1.6008793115615845], [1.2286080
# ...

# %%
"AAABBAABAAABABAABBAA" in list(data.keys())
# Out:
# True

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(*z_pred.T, '.', label='RNN')
# ax.plot(*z_pred_rev.T, 'x', label='RNN (reversed)')
xy = np.vstack(list(data.values()))
# ax.plot(*xy.T, 's', mfc='none', label='MD')
im = ax.scatter(*xy.T, c=np.array(list(range(10))*43), label='MD')
cb = plt.colorbar(im)
cb.set_label('Snapshot')
# ax.scatter(*xy[1::10].T, label='MD')
# ax.scatter(*xy[5::10].T, label='MD')
# ax.scatter(*xy[9::10].T, label='MD')
ax.plot(*orig_hull.T, 'k-', lw=0.5, zorder=-1)
ax.set_aspect('equal')
ax.legend()

# %%
# "sequence of sticky A, and non-sticky B bead"
membrane_str = "ABAAABBAAAABBABBBAAA"
print("A:", membrane_str.count("A"), "B:", membrane_str.count("B"))
# Out:
# A: 12 B: 8

# %%
# sequences = ["ABAAABBAAAABBABBBAAA", "BBAAABABAAABAAABBBAA"]  # these are examples from our 2021 paper
sequences = ["ABAAABBAAAABABBBBAAA", "BABBAAABAAABABBAABAA",
             "BBBABBABAABBAAAAAAAA", "BABBBBBABAABAAAAAAAA",
             "ABBAABBAAAAABABBBAAA", "ABABBABAAAAABBBABAAA",
             "BBBAAAABAABAABAABBAA", "BBBAAABAABAAABBAABAA",
             ]

AB = {'A': 0, 'B': 1}
int_seq = np.array([[int(AB[x]) for x in s] for s in sequences])

predictions = []
for model in model_ensemble:
    out = model_utils.predict_from_model(model, int_seq)
    predictions.append(out)
z_pred = np.array(predictions).mean(axis=0)

print('forward:', z_pred)

# AB_rev = {'A': 1, 'B': 0}
# int_seq = np.array([[int(AB_rev[x]) for x in s] for s in sequences])
# 
# predictions = []
# for model in model_ensemble:
#     out = model_utils.predict_from_model(model, int_seq)
#     predictions.append(out)
# z_pred_rev = np.array(predictions).mean(axis=0)
# 
# print('reversed:', z_pred_rev)
# Out:
# forward: [[ 1.4121448  8.824709 ]
#  [ 1.6574312  9.039579 ]
#  [ 2.6186857 -3.9103901]
#  [ 2.6991057 -4.2433844]
#  [-3.9749668  7.2053566]
#  [-4.1514473  7.1900635]
#  [ 5.6604333  9.869727 ]
#  [ 6.07577    9.621931 ]]

# %%
import json
import os
import message_utils

fp = os.path.join('data', 'llm-logs', 'seeded', 'scientific', 'liquid', 'claude-test-a826d293-17129254120.json')
with open(fp, 'r') as fid:
    data = json.load(fid)
with open(os.path.join('data', 'sequence-files', f'sequences-se-sci-liq-0.txt'), 'w') as fid:
    fid.write('')
k = 0
for m in data['messages']:
    if m['role'] != 'user':
        continue
    t = m['content'][0]['text']
    seq = message_utils.extract_AB_substrings(t)
    seq = [it for it in seq if len(it) == 20]
    with open(os.path.join('data', 'sequence-files', f'sequences-se-sci-liq-0.txt'), 'a') as fid:
        fid.write('\n'.join(seq) + '\n')
    k += 1

# %%
import target_defs
import torch
import model_utils

# load the RNN
model_ensemble = []
model_path = os.path.join('models', 'gru-opt-cv10-sym')
for i in range(10):
    model = torch.jit.load(os.path.join(model_path, f'fold-{i:02d}-scripted.pt'), map_location='cpu')
    model.eval()
    model_ensemble.append(model)

abc = 'abcdefghijkl'

short_names = {'liquid': 'liq',
               'string': 'str',
               'membrane': 'mem',
               'vesicle': 'ves',
               'wormlike micelle': 'wlm',
               'spherical micelle': 'spm',
               }

# %%
fig, axes = plt.subplots(2, 3, figsize=(7, 3.25), sharex='all', sharey='all')
fig.subplots_adjust(wspace=0, hspace=0)
axes = axes.flatten()

for i, morph in enumerate(short_names.keys()):
    
    ax = axes[i]
    
    data = {}
    for k in range(11):
        # with open(f'/Users/wfr5091/Downloads/embeddings-{k:d}.json', 'r') as fid:
        # with open(f'/Users/wfr5091/Downloads/se-sci-0-embeddings/embeddings-{k:02d}.json', 'r') as fid:
        with open(f'/Users/wfr5091/Downloads/se-sci-0-embeddings/embeddings-{short_names[morph]}.json', 'r') as fid:
            buffer = json.load(fid)
        data.update(buffer)
    
    target = target_defs.archetype_predictions[morph]
    
    sequences = list(data.keys())  
    
    AB = {'A': 0, 'B': 1}
    int_seq = np.array([[int(AB[x]) for x in s] for s in sequences])
    
    predictions = []
    for model in model_ensemble:
        out = model_utils.predict_from_model(model, int_seq)
        predictions.append(out)
    z_pred = np.array(predictions).mean(axis=0)
    
    show_idx = np.ones(z_pred.shape[0], dtype=bool)
    # show_idx = z_pred[:, 0] > 19.2  # for liquid
    # show_idx = z_pred[:, 0] < -3.75  # for strings
    
    xy = np.vstack(list(data.values()))
    d_to_t = np.linalg.norm(xy - target, axis=1)
    n_in_d = np.sum(d_to_t < 1.34)
    r_to_t = np.linalg.norm(z_pred - target, axis=1)
    n_in_r = np.sum(r_to_t < 1.34)
    # ax.text(0.01, 0.99, f"MD found {n_in_d} sequences compared to {n_in_r} from RNN",
    #         transform=ax.transAxes, ha='left', va='top')
    
    ax.plot(*z_pred[show_idx].T, '.', ms=6, mew=0.5, mfc='none', label=f'RNN $(k={n_in_r})$', zorder=2)
    ax.plot(*xy[show_idx].T, 's', ms=2, mew=0.5, mfc='none', label=f'MD $(k={n_in_d})$', zorder=3)
    ax.plot(*orig_hull.T, 'k-', lw=0.5, zorder=-1)
    ax.set_aspect('equal')
    ax.legend(fontsize=7, ncol=1, markerscale=1.0, borderpad=0.1, labelspacing=0.1, handletextpad=0.1, columnspacing=0,
              loc='upper right', bbox_to_anchor=(0.975, 0.975),  borderaxespad=0, frameon=False)
    
    ax.text(0.025, 0.975, f"({abc[i]})", fontsize=8, transform=ax.transAxes, ha='left', va='top')
    morph_str = '\n'.join(morph.title().split())
    ax.text(0.95, 0.05, f"{morph_str}", fontsize=7, transform=ax.transAxes, ha='right', va='bottom')
    
    # plt.plot(*target, 'ko', label='Target')
    t = np.linspace(0, 2*np.pi)
    circ_points = np.vstack([np.cos(t), np.sin(t)]).T  # radius = 1
    ax.plot(*(1.34 * circ_points + target).T, 'k:', lw=0.5, alpha=1.0, zorder=10, label='Target')
    
    lines = np.zeros([0, 2])
    for i in range(xy.shape[0]):
        if not show_idx[i]:
            continue
        lines = np.vstack([lines, xy[i], z_pred[i], np.nan*np.ones(2)])
        this = np.vstack([xy[i], z_pred[i]])
        ax.plot(*this.T, c='grey', lw=0.5, alpha=0.33, zorder=0)
    # ax.plot(*lines.T, c='grey', alpha=0.33, rasterized=True)
    
fig.tight_layout()

# %%
fig.savefig('md-validation.pdf', dpi=300, bbox_inches='tight')
